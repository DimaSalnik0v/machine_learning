# %% [markdown]
# 14 ЛАБ. РАБОТА

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
import cv2

model = YOLO('yolov8n.pt') # загрузка предобученной модели
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# РАЗМЕТКА (люди в маска / люди без масок)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Обучение модели

# %%
results = model.train(data='mask wearing.v2-release.yolov8/data.yaml', epochs=10, imgsz=640, device ='mps')
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.7 torch-2.1.1+cpu CPU (AMD Ryzen 5 5625U with Radeon Graphics)
# ...

# %% [markdown]
# Графики

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img_list = [
    f'mask wearing.v2-release.yolov8/test/images/w1240-p16x9-0e48e0098f6e832f27d8b581b33bbc72b9967a63_jpg.rf.d9a95a8a95c9698b818c218c351d4a46.jpg',
    f'mask wearing.v2-release.yolov8/test/images/126202-untitled-design-13_jpg.rf.e7f355f972d787ad631c27c79fb8f257.jpg',
    f'mask wearing.v2-release.yolov8/test/images/15391513329330sooq10859_jpg.rf.72cb60e72cf02fe7f905ca5343882bca.jpg',
    f'mask wearing.v2-release.yolov8/test/images/1224331650_g_400-w_g_jpg.rf.2cb01f1b9e9f0b776d9631d83a58c3e8.jpg'
]

res_predict = model.predict(img_list)

for res in res_predict:  
    boxes = res.boxes
# print(boxes)
# Out:
# 0: 640x640 2 masks, 1: 640x640 2 masks, 2: 640x640 1 mask, 3: 640x640 1 mask, 527.7ms
# Speed: 7.7ms preprocess, 131.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
fig, ax = plt.subplots(1 , 4, figsize=(20,4), sharex=False,sharey=False)
for i, result in enumerate(res_predict):
    ax[i].axis('on')
    ax[i].imshow(cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB))
plt.show()
